# %%
import sys
sys.path.append(r'C:\Users\USER\Desktop\spark-kurs\Projekt\loaders')
sys.path.append(r'C:\Users\USER\Desktop\spark-kurs\Projekt\cleaners')
sys.path.append(r'C:\Users\USER\Desktop\spark-kurs\Projekt\analyzers')

from IPython.core.display import HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))

import os
os.environ['PYSPARK_HOME']= r"C:\Users\USER\Desktop\spark-kurs\Projekt"
os.environ['PYSPARK_DRIVER_PYTHON']= "jupyter"
os.environ['PYSPARK_DRIVER_PYTHON_OPTS'] = 'lab'
os.environ['PYSPARK_PYTHON'] = 'python'

from pyspark.sql import SparkSession, Row
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, LongType, FloatType
from pyspark.sql.functions import col, split, explode, sha2, round, avg, udf

from tweets_loader import TweetsLoader
from tweets_cleaner import TweetsCleaner
from tweets_analyzer import TweetsAnalyzer
from tweets_search import TweetsSearcher

spark = SparkSession.builder \
        .appName("projekt") \
        .config("spark.executor.memory", "2g") \
        .config("spark.driver.memory", "2g") \
        .master("local[*]") \
        .getOrCreate()
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
tweets_loader = TweetsLoader()
tweets_cleaner = TweetsCleaner()
tweets_analyzer = TweetsAnalyzer()
tweets_searcher = TweetsSearcher()

all_tweets_df = tweets_loader.load_all_tweets({
    "covid": r"C:\Users\USER\Desktop\spark-kurs\Projekt\data\covid19_tweets.csv",
    "grammys": r"C:\Users\USER\Desktop\spark-kurs\Projekt\data\GRAMMYs_tweets.csv",
    "financial": r"C:\Users\USER\Desktop\spark-kurs\Projekt\data\financial.csv"
})

tweets_cleaner = tweets_cleaner.clean_all_tweets(all_tweets_df)

tweets_analyzer.calculate_hashtags(tweets_cleaner).show()
tweets_analyzer.calculate_is_retweet(tweets_cleaner).show()
tweets_analyzer.calculate_source(tweets_cleaner).show()
tweets_analyzer.calculate_avg_user_followers_per_location(tweets_cleaner).show()

tweets_searcher.search_by_key_words(["COVID-19"], tweets_cleaner).show()
# Out:
# +--------------------+-----+
# |            hashtags|count|
# +--------------------+-----+
# |               hanna|    1|
# |           Workplace|    3|
# |    staysafeeveryone|    1|
# |  socialconditioning|    2|
# |          Ulhasnagar|    1|
# |               squad|    1|
# |                arzt|    1|
# |              travel|   13|
# |Covid19isGettingC...|    1|
# |     NVIDIAInception|    1|
# |          LosAngeles|    8|
# |              myteam|    1|
# | YouAreNotInvincible|    1|
# |           HEROESact|   10|
# |                 art|   13|
# |        InformaGente|    1|
# |           realitytv|    1|
# |             Antwerp|    3|
# |            arrogant|    1|
# |              rakhis|    1|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
# |          is_retweet|count|
# +--------------------+-----+
# |           #BREAKING|    1|
# | Kenya and Djibou...|    1|
# |What have we come...|    1|
# | but GCRMC has no...|    1|
# |El Cañonazo de las 9|    3|
# |… https://t.co/St...|    1|
# |@dawn_com Censors...|    1|
# |                 101|    2|
# |And here I though...|    1|
# |['COVID19', 'horr...|    1|
# |     ['ToosieSlide']|    1|
# |['coronavirus', '...|    1|
# | if you found out...|    1|
# |                5820|    1|
# | taking care… htt...|    1|
# |         ['covid19']|    3|
# |['MLSisBack', 'CO...|    1|
# |['NSTsports', 'Qa...|    1|
# |           Metricool|    1|
# |['coronavirus', '...|    1|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
# |              source|count|
# +--------------------+-----+
# |                 467|    1|
# |To suggest there ...|    1|
# |    Meltwater Social|    5|
# |  ['Trump', 'Tesla']|    1|
# |App for IconicHip...|    4|
# |   ['COVID19', 'US']|    1|
# |            teachers|    1|
# |#COVID19 has done...|    1|
# |['Covid19', 'coro...|    1|
# |      CrowdControlHQ|    2|
# |      Konnect Social|    1|
# |['cañonazo', 'hav...|    3|
# |             TTYtter|    5|
# |['COVID19', 'Loui...|    1|
# |           Freshdesk|    4|
# | 2020-07-27 01:56:58|    1|
# |000 range — and t...|    1|
# |          Zapier.com|   17|
# |    AtlantaTechBlogs|    1|
# |['Gohmert', 'COVI...|    1|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+------------------+
# |       user_location|avg_user_followers|
# +--------------------+------------------+
# |              Heaven|             274.0|
# |Grimsby & Great H...|             792.0|
# |    Redhill, England|            2085.0|
# |     Gainesville, FL|  8314.57142857143|
# |            Novi, MI|            2344.0|
# |           Bangalore| 6651.512195121952|
# |               Mainz|             508.0|
# |   St Petersburg, FL|2179.4444444444443|
# |       St George, UT|             240.0|
# |           Bixby, OK|            1085.0|
# |           Worcester|            4797.0|
# | Mumbai, Maharashtra| 12847.09090909091|
# |Washington, D.C.,...|             329.0|
# |𝓘 𝓪𝓲𝓷𝓽 𝓰𝓸?...|              64.0|
# |      West Vancouver|            2744.0|
# |      Luton, England|15962.666666666666|
# |               Bucks|             429.0|
# |Blackpool, Lancs,...|             728.0|
# |ÜT: -26.532499,28...|             596.0|
# |Twilight Zone on ...|             361.0|
# +--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+--------------------+--------------------+------------+--------------+------------+---------------+-------------+----------+--------------------+--------------------+-------------------+----------+--------+----+---------+-------+-------------+----+--------+
# |           user_name|       user_location|    user_description|user_created|user_followers|user_friends|user_favourites|user_verified|      date|                text|            hashtags|             source|is_retweet|category|  id|timestamp|symbols|company_names| url|verified|
# +--------------------+--------------------+--------------------+------------+--------------+------------+---------------+-------------+----------+--------------------+--------------------+-------------------+----------+--------+----+---------+-------+-------------+----+--------+
# |EKITI COVID19 UPD...|      Ekiti, Nigeria|Official Twitter ...|  2019-11-13|           865|           3|             28|        False|2020-07-25|EKITI COVID-19 UP...|           [COVID19]| Twitter for iPhone|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |         Inves2money|                  EU|Blogger & SEO #fi...|  2016-04-02|           286|         489|            371|        False|2020-07-25|An expert explain...|           [covid19]|           Paper.li|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |       Global Policy|Durham University...|We are the Global...|  2010-03-26|         11354|        3846|           2637|        False|2020-07-25|Open Access GP Es...|[COVID19,  Tracin...|     Hootsuite Inc.|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |   Maryellen Alvarez|     New Jersey, USA|Patriot/Cat lover...|  2012-09-19|            58|         180|           6845|        False|2020-07-25|CDC changes COVID...|[COVID19,  theyha...|   Twitter for iPad|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |        India Blooms|               India|A news and refere...|  2009-10-10|         15241|        2445|             17|        False|2020-07-25|Bangladesh record...|[Bangladesh,  COV...|    Twitter Web App|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |Journalist Siraj ...|              mumbai|Journalist @hatho...|  2010-08-22|           624|        2683|           3337|        False|2020-07-25|#Rajasthan Govern...|         [Rajasthan]|Twitter for Android|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |    Outbreak Science|       United States|A nonprofit to ad...|  2016-02-12|          1204|          41|             14|        False|2020-07-25|New #COVID19 prep...|           [COVID19]|     preprint-alert|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |          NewsMobile|               India|NewsMobile is a f...|  2013-12-26|         15325|          88|           3512|         True|2020-07-25|Rajasthan Governm...|        [PlasmaBank]|          TweetDeck|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |National Cyber Se...|         Atlanta, GA|"We are a leader ...|  2010-01-27|          5425|         161|              8|        False|2020-07-25|FBI warns of COVI...|[coronavirus,  sc...|      WordPress.com|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# |                 Jai|Previously Bangal...|Inquisitive Entre...|  2009-12-24|           273|        1478|           1589|        False|2020-07-25|Societal upheaval...|           [covid19]|           Paper.li|     False|   covid|NULL|     NULL|   NULL|         NULL|NULL|    NULL|
# +--------------------+--------------------+--------------------+------------+--------------+------------+---------------+-------------+----------+--------------------+--------------------+-------------------+----------+--------+----+---------+-------+-------------+----+--------+
# only showing top 20 rows
